# %% [markdown]
# ## Get into ES
#
# cd elasticsearch-6.1.1/bin
#
# ./elasticsearch

# %% [markdown]
# ## Make sure ES is running:

# %%
import requests
res = requests.get('http://localhost:9200')
print(res.content)
# Out:
# b'{\n  "name" : "P6we63q",\n  "cluster_name" : "elasticsearch",\n  "cluster_uuid" : "GMQoOO63T_yJwEJhf6J-0w",\n  "version" : {\n    "number" : "6.1.1",\n    "build_hash" : "bd92e7f",\n    "build_date" : "2017-12-17T20:23:25.338Z",\n    "build_snapshot" : false,\n    "lucene_version" : "7.1.0",\n    "minimum_wire_compatibility_version" : "5.6.0",\n    "minimum_index_compatibility_version" : "5.0.0"\n  },\n  "tagline" : "You Know, for Search"\n}\n'

# %% [markdown]
#  ## Connect to ES cluster:

# %%
from elasticsearch import Elasticsearch
es = Elasticsearch([{'host': 'localhost', 'port': 9200}])

# %% [markdown]
# ## Look for my data

# %%
ls
# Out:
# data/  ES_testing.ipynb  ghostdriver.log  notebooks/  README.md  src/  web_app/

# %%
cd data
# Out:
# /home/karen/Documents/ski-recommender/data

# %%
ls
# Out:
# Alpine_Meadows.txt  Crested_Butte.txt  Eldora.txt    new/              Vail.txt
# Arapahoe_Basin.txt  df2.pkl            Loveland.txt  resort_dict2.pkl  WP.csv
# Beaver_Creek.txt    df.pkl             Monarch.txt   resort_dict.pkl
# Copper.txt          DP.txt             mtn_df.pkl    Taos.txt

# %% [markdown]
# ## Import dataframe with Trail data:

# %%
import pickle

# %%
pkl_file = open('df.pkl', 'rb')
df = pickle.load(pkl_file)
pkl_file.close()

# %%
df
# Out:
#               trail_name  top_elev_(ft)  bottom_elev_(ft)  vert_rise_(ft)  \
# 0       Over the Rainbow        11924.0           10858.0          1066.0
# 1                   Zoom        11405.0           11005.0           400.0
# 2         Avalanche Bowl        11840.0           11405.0           435.0
# 3           Tiger's Tail        11856.0           11469.0           386.0
# 4               Spillway        11849.0           11631.0           218.0
# 5              Waterfall        11638.0           11515.0           124.0
# 6        Upper Richard's        11816.0           11702.0           113.0
# 7               Cat Walk        11856.0           11644.0           212.0
# 8               Holy Cat        11141.0           10917.0           224.0
# 9             Busy Gully        11421.0           10903.0           518.0
# 10             Cats Meow        11515.0           10889.0           625.0
# 11               Nix Nox        11530.0           11023.0           507.0
# 12         Richard's Run        11633.0           11120.0           513.0
# 13                 Mambo        11652.0           11181.0           471.0
# 14               Tempest        11695.0           11392.0           303.0
# 15         Excelleration        11720.0           11446.0           275.0
# 16              Home Run        11200.0           10895.0           305.0
# 17            Tango Road        11121.0           10999.0           123.0
# 18        Bennett's Bowl        11984.0           11614.0           370.0
# 19             Fire Bowl        11978.0           11631.0           347.0
# 20    North Turtle Creek        11617.0           11342.0           274.0
# 21               Drifter        11556.0           11268.0           288.0
# 22              Fire Cut        11613.0           11121.0           491.0
# 23              Tomahawk        11712.0           11445.0           267.0
# 24        Apollo (Lower)        11900.0           11592.0           308.0
# 25        Apollo (Upper)        12193.0           11898.0           295.0
# 26               Mercury        12137.0           11706.0           431.0
# 27              Telestar        12187.0           11887.0           299.0
# 28         Sunburst Bowl        12197.0           11866.0           331.0
# 29          North Chutes        11850.0           11507.0           342.0
# ...                  ...            ...               ...             ...
# 1095         Ridge Point         7767.0            7651.0           115.0
# 1096              Rubarb         8247.0            8003.0           244.0
# 1097             Sawbuck         9437.0            8504.0           932.0
# 1098             Stirrup         9350.0            8420.0           930.0
# 1099            Bear Paw         8517.0            8497.0            20.0
# 1100           Cold Snap         8531.0            8487.0            44.0
# 1101              Cresta         9094.0            7409.0          1685.0
# 1102            Crossbow         9017.0            8982.0            36.0
# 1103           Everkrisp         8332.0            8276.0            56.0
# 1104               Flint         7831.0            7538.0           293.0
# 1105         Golden Bear         9010.0            7476.0          1534.0
# 1106    Homeowner Skiway         8321.0            7976.0           345.0
# 1107            Larkspur        10364.0            8886.0          1478.0
# 1108        Little Brave         8992.0            7584.0          1408.0
# 1109       Piece O' Cake         9110.0            7605.0          1505.0
# 1110             Pow Wow         8980.0            8555.0           425.0
# 1111           Roughlock         8638.0            8122.0           516.0
# 1112         Springtooth         8855.0            8523.0           332.0
# 1113            Tomahawk         8534.0            7542.0           992.0
# 1114               Wapti         9080.0            8109.0           971.0
# 1115   BC Mtn Expressway         9849.0            8862.0           987.0
# 1116  Beginner Terrain 1         8106.0            8100.0             6.0
# 1117  Beginner Terrain 2         8106.0            8100.0             6.0
# 1118  Beginner Terrain 3         8129.0            8100.0            29.0
# 1119  Beginner Terrain 4         8117.0            8100.0            17.0
# 1120  Beginner Terrain 5         8140.0            8100.0            40.0
# 1121  Beginner Terrain 6         8127.0            8100.0            27.0
# 1122  Beginner Terrain 7         8110.0            8100.0            10.0
# 1123  Beginner Terrain 8         8113.0            8100.0            13.0
# 1124  Beginner Terrain 9         8147.0            8100.0            47.0
#
#       slope_length_(ft)  avg_width_(ft)  slope_area_(acres)  avg_grade_(%)  \
# 0                2404.0           319.0                17.6           50.0
# 1                 839.0           195.0                 3.7           55.0
# 2                1141.0           255.0                 6.7           42.0
# 3                1183.0           136.0                 3.7           35.0
# 4                 702.0           198.0                 3.2           33.0
# 5                 370.0           172.0                 1.5           36.0
# 6                 348.0           159.0                 1.3           35.0
# 7                1830.0            63.0                 2.7           12.0
# 8                 505.0            90.0                 1.0           50.0
# 9                1394.0           115.0                 3.7           41.0
# 10               1806.0           144.0                 6.0           38.0
# 11               1658.0           153.0                 5.8           32.0
# 12               1931.0           156.0                 6.9           28.0
# 13               2095.0           149.0                 7.2           23.0
# 14               1306.0           117.0                 3.5           24.0
# 15               1006.0           131.0                 3.0           29.0
# 16               2333.0           174.0                 9.3           13.0
# 17               1297.0            97.0                 2.9           10.0
# 18               1833.0           567.0                23.9           21.0
# 19               2447.0           432.0                24.3           14.0
# 20               1264.0           231.0                 6.7           22.0
# 21               1191.0           107.0                 2.9           25.0
# 22               1985.0           244.0                11.1           26.0
# 23                888.0           178.0                 3.6           32.0
# 24                905.0           256.0                 5.3           37.0
# 25               1901.0           249.0                10.9           16.0
# 26               1986.0           932.0                42.5           22.0
# 27               1249.0           309.0                 8.9           25.0
# 28               1702.0           861.0                33.6           20.0
# 29               1032.0           204.0                 4.8           35.0
# ...                 ...             ...                 ...            ...
# 1095             1895.0            34.0                 1.5            6.0
# 1096             3442.0            40.0                 3.1            7.0
# 1097             4554.0           287.0                30.1           21.0
# 1098             8933.0            35.0                 7.2            9.0
# 1099             1155.0            26.0                 0.7            2.0
# 1100              451.0            26.0                 0.3           10.0
# 1101             8379.0           161.0                30.9           21.0
# 1102              300.0           186.0                 1.3           12.0
# 1103              682.0            40.0                 0.6            8.0
# 1104             1079.0           229.0                 5.7           29.0
# 1105             6606.0           233.0                35.3           24.0
# 1106             3700.0            20.0                 1.7            9.0
# 1107             6060.0           411.0                57.1           28.0
# 1108             7501.0           113.0                19.4           19.0
# 1109            15524.0            18.0                 6.5           10.0
# 1110             2346.0           187.0                10.1           18.0
# 1111             3092.0            91.0                 6.4           17.0
# 1112             1768.0            79.0                 3.2           19.0
# 1113             3843.0           104.0                 9.1           27.0
# 1114             4024.0           133.0                12.3           25.0
# 1115            11019.0            58.0                14.7            9.0
# 1116               80.0           100.0                 0.2            8.0
# 1117               80.0           120.0                 0.2            8.0
# 1118              240.0           110.0                 0.6           12.0
# 1119              120.0           140.0                 0.4            7.0
# 1120              338.0           160.0                 1.3           12.0
# 1121              300.0           130.0                 0.9            9.0
# 1122              120.0            90.0                 0.2            8.0
# 1123              110.0           120.0                 0.3           12.0
# 1124              320.0           160.0                 1.2           15.0
#
#       max_grade_(%)     ability_level        resort location  groomed colors  \
# 0              69.0            Expert      Loveland       CO        0     bb
# 1              66.0            Expert      Loveland       CO        0     bb
# 2              76.0            Expert      Loveland       CO        0     bb
# 3              61.0            Expert      Loveland       CO        0  black
# 4              41.0      Intermediate      Loveland       CO        1   blue
# 5              45.0          Advanced      Loveland       CO        0   blue
# 6              38.0      Intermediate      Loveland       CO        0   blue
# 7              31.0  Low Intermediate      Loveland       CO        1  green
# 8              67.0            Expert      Loveland       CO        0  black
# 9              65.0            Expert      Loveland       CO        0  black
# 10             65.0            Expert      Loveland       CO        0  black
# 11             50.0          Advanced      Loveland       CO        0   blue
# 12             37.0      Intermediate      Loveland       CO        1   blue
# 13             28.0  Low Intermediate      Loveland       CO        1  green
# 14             35.0      Intermediate      Loveland       CO        1   blue
# 15             47.0          Advanced      Loveland       CO        0   blue
# 16             22.0            Novice      Loveland       CO        1  green
# 17             16.0            Novice      Loveland       CO        1  green
# 18             31.0  Low Intermediate      Loveland       CO        0   blue
# 19             27.0            Novice      Loveland       CO        1  green
# 20             26.0            Novice      Loveland       CO        1  green
# 21             31.0  Low Intermediate      Loveland       CO        1   blue
# 22             40.0      Intermediate      Loveland       CO        0   blue
# 23             47.0          Advanced      Loveland       CO        0   blue
# 24             59.0            Expert      Loveland       CO        0   blue
# 25             28.0          Advanced      Loveland       CO        1   blue
# 26             31.0  Low Intermediate      Loveland       CO        0   blue
# 27             40.0      Intermediate      Loveland       CO        1   blue
# 28             33.0      Intermediate      Loveland       CO        0   blue
# 29             53.0          Advanced      Loveland       CO        0   blue
# ...             ...               ...           ...      ...      ...    ...
# 1095           30.0  Low Intermediate  Beaver Creek       CO        0  green
# 1096           36.0      Intermediate  Beaver Creek       CO        0  green
# 1097           36.0      Intermediate  Beaver Creek       CO        1  green
# 1098           15.0            Novice  Beaver Creek       CO        1  green
# 1099           26.0  Low Intermediate  Beaver Creek       CO        0  green
# 1100           18.0            Novice  Beaver Creek       CO        0  green
# 1101           47.0          Advanced  Beaver Creek       CO        1   blue
# 1102           13.0            Novice  Beaver Creek       CO        0   blue
# 1103           16.0            Novice  Beaver Creek       CO        0  green
# 1104           55.0          Advanced  Beaver Creek       CO        0  black
# 1105           43.0      Intermediate  Beaver Creek       CO        1   blue
# 1106           19.0            Novice  Beaver Creek       CO        0  green
# 1107           45.0      Intermediate  Beaver Creek       CO        1   blue
# 1108           38.0      Intermediate  Beaver Creek       CO        1  green
# 1109           35.0      Intermediate  Beaver Creek       CO        0  green
# 1110           26.0  Low Intermediate  Beaver Creek       CO        0   blue
# 1111           39.0      Intermediate  Beaver Creek       CO        1   blue
# 1112           37.0      Intermediate  Beaver Creek       CO        1   blue
# 1113           49.0          Advanced  Beaver Creek       CO        0  black
# 1114           49.0          Advanced  Beaver Creek       CO        0   blue
# 1115           15.0            Novice  Beaver Creek       CO        1  green
# 1116            9.0          Beginner  Beaver Creek       CO        1  green
# 1117           10.0          Beginner  Beaver Creek       CO        1  green
# 1118           12.0          Beginner  Beaver Creek       CO        1  green
# 1119            9.0          Beginner  Beaver Creek       CO        1  green
# 1120           12.0          Beginner  Beaver Creek       CO        1  green
# 1121           10.0          Beginner  Beaver Creek       CO        1  green
# 1122           11.0          Beginner  Beaver Creek       CO        1  green
# 1123           12.0          Beginner  Beaver Creek       CO        1  green
# 1124           12.0          Beginner  Beaver Creek       CO        1  green
#
#       ability_nums  color_nums
# 0                6           4
# 1                6           4
# 2                6           4
# 3                6           3
# 4                4           2
# 5                5           2
# 6                4           2
# 7                3           1
# 8                6           3
# 9                6           3
# 10               6           3
# 11               5           2
# 12               4           2
# 13               3           1
# 14               4           2
# 15               5           2
# 16               2           1
# 17               2           1
# 18               3           2
# 19               2           1
# 20               2           1
# 21               3           2
# 22               4           2
# 23               5           2
# 24               6           2
# 25               5           2
# 26               3           2
# 27               4           2
# 28               4           2
# 29               5           2
# ...            ...         ...
# 1095             3           1
# 1096             4           1
# 1097             4           1
# 1098             2           1
# 1099             3           1
# 1100             2           1
# 1101             5           2
# 1102             2           2
# 1103             2           1
# 1104             5           3
# 1105             4           2
# 1106             2           1
# 1107             4           2
# 1108             4           1
# 1109             4           1
# 1110             3           2
# 1111             4           2
# 1112             4           2
# 1113             5           3
# 1114             5           2
# 1115             2           1
# 1116             1           1
# 1117             1           1
# 1118             1           1
# 1119             1           1
# 1120             1           1
# 1121             1           1
# 1122             1           1
# 1123             1           1
# 1124             1           1
#
# [1125 rows x 16 columns]

# %% [markdown]
# ## Get data in dictionary form to be indexed

# %%
dict_df = df.to_dict(orient='records')

# %%
dict_df;

# %% [markdown]
# ## Index (looping over trails)

# %%
j=1
for i in dict_df:
    es.index(index='ski', doc_type='runs', id=j, body=i)
    j+=1

# %% [markdown]
# ## Check to make sure I get what I want back for a certain index

# %%
es.get(index='ski', doc_type='runs', id=5)
# Out:
# {'_id': '5',
#  '_index': 'ski',
#  '_source': {'ability_level': 'Intermediate',
#   'ability_nums': 4,
#   'avg_grade_(%)': 33.0,
#   'avg_width_(ft)': 198.0,
#   'bottom_elev_(ft)': 11631.0,
#   'color_nums': 2,
#   'colors': 'blue',
#   'groomed': 1,
#   'location': 'CO',
#   'max_grade_(%)': 41.0,
#   'resort': 'Loveland',
#   'slope_area_(acres)': 3.2,
#   'slope_length_(ft)': 702.0,
#   'top_elev_(ft)': 11849.0,
#   'trail_name': 'Spillway',
#   'vert_rise_(ft)': 218.0},
#  '_type': 'runs',
#  '_version': 1,
#  'found': True}

# %% [markdown]
# ## Try different searches!

# %%
es.search(index="ski", body={"query": {"match": {'trail_name':'Over the Rainbow'}}})
# Out:
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 5, 'total': 5},
#  'hits': {'hits': [{'_id': '1',
#     '_index': 'ski',
#     '_score': 10.562768,
#     '_source': {'ability_level': 'Expert',
#      'ability_nums': 6,
#      'avg_grade_(%)': 50.0,
#      'avg_width_(ft)': 319.0,
#      'bottom_elev_(ft)': 10858.0,
#      'color_nums': 4,
#      'colors': 'bb',
#      'groomed': 0,
#      'location': 'CO',
#      'max_grade_(%)': 69.0,
#      'resort': 'Loveland',
#      'slope_area_(acres)': 17.6,
#      'slope_length_(ft)': 2404.0,
#      'top_elev_(ft)': 11924.0,
#      'trail_name': 'Over the Rainbow',
#      'vert_rise_(ft)': 1066.0},
#     '_type': 'runs'},
#    {'_id': '925',
#     '_index': 'ski',
#     '_score': 4.405436,
#     '_source': {'ability_level': 'Advanced',
#      'ability_nums': 5,
#      'avg_grade_(%)': 33.0,
#      'avg_width_(ft)': 171.0,
#      'bottom_elev_(ft)': 9460.0,
#      'color_nums': 3,
#      'colors': 'black',
#      'groomed': 0,
#      'location': 'CO',
#      'max_grade_(%)': 45.0,
#      'resort': 'Winter Park',
#      'slope_area_(acres)': 14.69,
#      'slope_length_(ft)': 3174.18,
#      'top_elev_(ft)': 10450.0,
#      'trail_name': 'Rainbow Cut',
#      'vert_rise_(ft)': 990.0},
#     '_type': 'runs'},
#    {'_id': '96',
#     '_index': 'ski',
#     '_score': 4.3865075,
#     '_source': {'ability_level': 'Intermediate',
#      'ability_nums': 4,
#      'avg_grade_(%)': 36.0,
#      'avg_width_(ft)': 62.0,
#      'bottom_elev_(ft)': 11114.0,
#      'color_nums': 3,
#      'colors': 'black',
#      'groomed': 0,
#      'location': 'CO',
#      'max_grade_(%)': 44.0,
#      'resort': 'Arapahoe Basin',
#      'slope_area_(acres)': 1.3,
#      'slope_length_(ft)': 926.0,
#      'top_elev_(ft)': 11427.0,
#      'trail_name': 'The Gulch',
#      'vert_rise_(ft)': 313.0},
#     '_type': 'runs'},
#    {'_id': '117',
#     '_index': 'ski',
#     '_score': 4.3865075,
#     '_source': {'ability_level': 'Expert',
#      'ability_nums': 6,
#      'avg_grade_(%)': 58.0,
#      'avg_width_(ft)': 78.0,
#      'bottom_elev_(ft)': 11410.0,
#      'color_nums': 4,
#      'colors': 'bb',
#      'groomed': 0,
#      'location': 'CO',
#      'max_grade_(%)': 71.0,
#      'resort': 'Arapahoe Basin',
#      'slope_area_(acres)': 1.9,
#      'slope_length_(ft)': 1058.0,
#      'top_elev_(ft)': 11937.0,
#      'trail_name': 'The Spine',
#      'vert_rise_(ft)': 527.0},
#     '_type': 'runs'},
#    {'_id': '559',
#     '_index': 'ski',
#     '_score': 4.012029,
#     '_source': {'ability_level': 'Intermediate',
#      'ability_nums': 4,
#      'avg_grade_(%)': 32.0,
#      'avg_width_(ft)': 1093.0,
#      'bottom_elev_(ft)': 10009.0,
#      'color_nums': 3,
#      'colors': 'black',
#      'groomed': 0,
#      'location': 'CO',
#      'max_grade_(%)': 40.0,
#      'resort': 'Vail',
#      'slope_area_(acres)': 40.9,
#      'slope_length_(ft)': 1631.8,
#      'top_elev_(ft)': 10529.0,
#      'trail_name': 'Over Yonder',
#      'vert_rise_(ft)': 519.3},
#     '_type': 'runs'},
#    {'_id': '1007',
#     '_index': 'ski',
#     '_score': 4.012029,
#     '_source': {'ability_level': 'Expert',
#      'ability_nums': 6,
#      'avg_grade_(%)': 31.0,
#      'avg_width_(ft)': 617.14,
#      'bottom_elev_(ft)': 10850.0,
#      'color_nums': 3,
#      'colors': 'black',
#      'groomed': 0,
#      'location': 'CO',
#      'max_grade_(%)': 83.0,
#      'resort': 'Winter Park',
#      'slope_area_(acres)': 23.86,
#      'slope_length_(ft)': 1684.13,
#      'top_elev_(ft)': 11350.0,
#      'trail_name': 'Roll Over',
#      'vert_rise_(ft)': 500.0},
#     '_type': 'runs'},
#    {'_id': '444',
#     '_index': 'ski',
#     '_score': 3.79454,
#     '_source': {'ability_level': 'Low Intermediate',
#      'ability_nums': 3,
#      'avg_grade_(%)': 15.0,
#      'avg_width_(ft)': 324.0,
#      'bottom_elev_(ft)': 10156.0,
#      'color_nums': 1,
#      'colors': 'green',
#      'groomed': 1,
#      'location': 'CO',
#      'max_grade_(%)': 31.0,
#      'resort': 'Vail',
#      'slope_area_(acres)': 29.5,
#      'slope_length_(ft)': 3967.9,
#      'top_elev_(ft)': 10768.0,
#      'trail_name': 'The Meadows',
#      'vert_rise_(ft)': 612.1},
#     '_type': 'runs'},
#    {'_id': '500',
#     '_index': 'ski',
#     '_score': 3.79454,
#     '_source': {'ability_level': 'Intermediate',
#      'ability_nums': 4,
#      'avg_grade_(%)': 26.0,
#      'avg_width_(ft)': 199.0,
#      'bottom_elev_(ft)': 8329.0,
#      'color_nums': 2,
#      'colors': 'blue',
#      'groomed': 1,
#      'location': 'CO',
#      'max_grade_(%)': 47.0,
#      'resort': 'Vail',
#      'slope_area_(acres)': 17.0,
#      'slope_length_(ft)': 3718.5,
#      'top_elev_(ft)': 9287.0,
#      'trail_name': 'The Preserve',
#      'vert_rise_(ft)': 957.5},
#     '_type': 'runs'},
#    {'_id': '365',
#     '_index': 'ski',
#     '_score': 3.7701063,
#     '_source': {'ability_level': 'Expert',
#      'ability_nums': 6,
#      'avg_grade_(%)': 42.0,
#      'avg_width_(ft)': 312.0,
#      'bottom_elev_(ft)': 7276.0,
#      'color_nums': 3,
#      'colors': 'black',
#      'groomed': 0,
#      'location': 'CA',
#      'max_grade_(%)': 70.0,
#      'resort': 'Alpine Meadows',
#      'slope_area_(acres)': 10.1,
#      'slope_length_(ft)': 1416.0,
#      'top_elev_(ft)': 7814.0,
#      'trail_name': 'The Face',
#      'vert_rise_(ft)': 539.0},
#     '_type': 'runs'},
#    {'_id': '452',
#     '_index': 'ski',
#     '_score': 3.7701063,
#     '_source': {'ability_level': 'Expert',
#      'ability_nums': 6,
#      'avg_grade_(%)': 28.0,
#      'avg_width_(ft)': 123.0,
#      'bottom_elev_(ft)': 10600.0,
#      'color_nums': 3,
#      'colors': 'black',
#      'groomed': 0,
#      'location': 'CO',
#      'max_grade_(%)': 59.0,
#      'resort': 'Vail',
#      'slope_area_(acres)': 3.2,
#      'slope_length_(ft)': 1111.3,
#      'top_elev_(ft)': 10912.0,
#      'trail_name': 'The Skipper',
#      'vert_rise_(ft)': 311.4},
#     '_type': 'runs'}],
#   'max_score': 10.562768,
#   'total': 25},
#  'timed_out': False,
#  'took': 325}

# %% [markdown]
# Match will match any terms in the query

# %%
es.search(index="ski", body={"query": {"match_phrase": {'trail_name':'Over the Rainbow'}}})
# Out:
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 5, 'total': 5},
#  'hits': {'hits': [{'_id': '1',
#     '_index': 'ski',
#     '_score': 10.562768,
#     '_source': {'ability_level': 'Expert',
#      'ability_nums': 6,
#      'avg_grade_(%)': 50.0,
#      'avg_width_(ft)': 319.0,
#      'bottom_elev_(ft)': 10858.0,
#      'color_nums': 4,
#      'colors': 'bb',
#      'groomed': 0,
#      'location': 'CO',
#      'max_grade_(%)': 69.0,
#      'resort': 'Loveland',
#      'slope_area_(acres)': 17.6,
#      'slope_length_(ft)': 2404.0,
#      'top_elev_(ft)': 11924.0,
#      'trail_name': 'Over the Rainbow',
#      'vert_rise_(ft)': 1066.0},
#     '_type': 'runs'}],
#   'max_score': 10.562768,
#   'total': 1},
#  'timed_out': False,
#  'took': 44}

# %% [markdown]
# Match phrase will match the exact phrase in the query

# %%
es.search(index="ski", body={"query": {"match_phrase_prefix": {'trail_name':'Over'}}})
# Out:
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 5, 'total': 5},
#  'hits': {'hits': [{'_id': '189',
#     '_index': 'ski',
#     '_score': 6.210478,
#     '_source': {'ability_level': 'Advanced',
#      'ability_nums': 5,
#      'avg_grade_(%)': 34.0,
#      'avg_width_(ft)': 165.0,
#      'bottom_elev_(ft)': 9925.0,
#      'color_nums': 3,
#      'colors': 'black',
#      'groomed': 0,
#      'location': 'CO',
#      'max_grade_(%)': 48.0,
#      'resort': 'Copper',
#      'slope_area_(acres)': 10.5,
#      'slope_length_(ft)': 2778.0,
#      'top_elev_(ft)': 10828.0,
#      'trail_name': 'Overlode',
#      'vert_rise_(ft)': 903.0},
#     '_type': 'runs'},
#    {'_id': '436',
#     '_index': 'ski',
#     '_score': 6.1848407,
#     '_source': {'ability_level': 'Low Intermediate',
#      'ability_nums': 3,
#      'avg_grade_(%)': 18.0,
#      'avg_width_(ft)': 238.0,
#      'bottom_elev_(ft)': 10237.0,
#      'color_nums': 1,
#      'colors': 'green',
#      'groomed': 1,
#      'location': 'CO',
#      'max_grade_(%)': 31.0,
#      'resort': 'Vail',
#      'slope_area_(acres)': 9.8,
#      'slope_length_(ft)': 1794.3,
#      'top_elev_(ft)': 10567.0,
#      'trail_name': 'Overeasy',
#      'vert_rise_(ft)': 330.1},
#     '_type': 'runs'},
#    {'_id': '1073',
#     '_index': 'ski',
#     '_score': 6.1544876,
#     '_source': {'ability_level': 'Novice',
#      'ability_nums': 2,
#      'avg_grade_(%)': 10.0,
#      'avg_width_(ft)': 52.0,
#      'bottom_elev_(ft)': 9324.0,
#      'color_nums': 2,
#      'colors': 'blue',
#      'groomed': 0,
#      'location': 'CO',
#      'max_grade_(%)': 17.0,
#      'resort': 'Beaver Creek',
#      'slope_area_(acres)': 2.3,
#      'slope_length_(ft)': 1886.0,
#      'top_elev_(ft)': 9512.0,
#      'trail_name': 'Overshot',
#      'vert_rise_(ft)': 188.0},
#     '_type': 'runs'},
#    {'_id': '211',
#     '_index': 'ski',
#     '_score': 4.8530383,
#     '_source': {'ability_level': 'Expert',
#      'ability_nums': 6,
#      'avg_grade_(%)': 44.0,
#      'avg_width_(ft)': 126.0,
#      'bottom_elev_(ft)': 11216.0,
#      'color_nums': 3,
#      'colors': 'black',
#      'groomed': 0,
#      'location': 'CO',
#      'max_grade_(%)': 56.0,
#      'resort': 'Copper',
#      'slope_area_(acres)': 3.0,
#      'slope_length_(ft)': 1037.0,
#      'top_elev_(ft)': 11635.0,
#      'trail_name': 'Ute Overlook',
#      'vert_rise_(ft)': 419.0},
#     '_type': 'runs'},
#    {'_id': '1',
#     '_index': 'ski',
#     '_score': 4.0558224,
#     '_source': {'ability_level': 'Expert',
#      'ability_nums': 6,
#      'avg_grade_(%)': 50.0,
#      'avg_width_(ft)': 319.0,
#      'bottom_elev_(ft)': 10858.0,
#      'color_nums': 4,
#      'colors': 'bb',
#      'groomed': 0,
#      'location': 'CO',
#      'max_grade_(%)': 69.0,
#      'resort': 'Loveland',
#      'slope_area_(acres)': 17.6,
#      'slope_length_(ft)': 2404.0,
#      'top_elev_(ft)': 11924.0,
#      'trail_name': 'Over the Rainbow',
#      'vert_rise_(ft)': 1066.0},
#     '_type': 'runs'},
#    {'_id': '559',
#     '_index': 'ski',
#     '_score': 4.012029,
#     '_source': {'ability_level': 'Intermediate',
#      'ability_nums': 4,
#      'avg_grade_(%)': 32.0,
#      'avg_width_(ft)': 1093.0,
#      'bottom_elev_(ft)': 10009.0,
#      'color_nums': 3,
#      'colors': 'black',
#      'groomed': 0,
#      'location': 'CO',
#      'max_grade_(%)': 40.0,
#      'resort': 'Vail',
#      'slope_area_(acres)': 40.9,
#      'slope_length_(ft)': 1631.8,
#      'top_elev_(ft)': 10529.0,
#      'trail_name': 'Over Yonder',
#      'vert_rise_(ft)': 519.3},
#     '_type': 'runs'},
#    {'_id': '1007',
#     '_index': 'ski',
#     '_score': 4.012029,
#     '_source': {'ability_level': 'Expert',
#      'ability_nums': 6,
#      'avg_grade_(%)': 31.0,
#      'avg_width_(ft)': 617.14,
#      'bottom_elev_(ft)': 10850.0,
#      'color_nums': 3,
#      'colors': 'black',
#      'groomed': 0,
#      'location': 'CO',
#      'max_grade_(%)': 83.0,
#      'resort': 'Winter Park',
#      'slope_area_(acres)': 23.86,
#      'slope_length_(ft)': 1684.13,
#      'top_elev_(ft)': 11350.0,
#      'trail_name': 'Roll Over',
#      'vert_rise_(ft)': 500.0},
#     '_type': 'runs'},
#    {'_id': '900',
#     '_index': 'ski',
#     '_score': 3.3004894,
#     '_source': {'ability_level': 'Intermediate',
#      'ability_nums': 4,
#      'avg_grade_(%)': 36.0,
#      'avg_width_(ft)': 271.0,
#      'bottom_elev_(ft)': 9640.0,
#      'color_nums': 3,
#      'colors': 'black',
#      'groomed': 0,
#      'location': 'CO',
#      'max_grade_(%)': 44.0,
#      'resort': 'Winter Park',
#      'slope_area_(acres)': 9.74,
#      'slope_length_(ft)': 1373.56,
#      'top_elev_(ft)': 10110.0,
#      'trail_name': "Over N' Underwood",
#      'vert_rise_(ft)': 470.0},
#     '_type': 'runs'}],
#   'max_score': 6.210478,
#   'total': 8},
#  'timed_out': False,
#  'took': 13}

# %% [markdown]
# Match phrase prefix will match any word that starts with the query

# %%
es.search(index="ski", body={"query": {"range": {'vert_rise_(ft)': {'gte': '2000', 'lte': '2300'}}}})
# Out:
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 5, 'total': 5},
#  'hits': {'hits': [{'_id': '200',
#     '_index': 'ski',
#     '_score': 1.0,
#     '_source': {'ability_level': 'Intermediate',
#      'ability_nums': 4,
#      'avg_grade_(%)': 25.0,
#      'avg_width_(ft)': 140.0,
#      'bottom_elev_(ft)': 9785.0,
#      'color_nums': 2,
#      'colors': 'blue',
#      'groomed': 1,
#      'location': 'CO',
#      'max_grade_(%)': 46.0,
#      'resort': 'Copper',
#      'slope_area_(acres)': 28.8,
#      'slope_length_(ft)': 8946.0,
#      'top_elev_(ft)': 11921.0,
#      'trail_name': 'Collage',
#      'vert_rise_(ft)': 2136.0},
#     '_type': 'runs'},
#    {'_id': '1053',
#     '_index': 'ski',
#     '_score': 1.0,
#     '_source': {'ability_level': 'Expert',
#      'ability_nums': 6,
#      'avg_grade_(%)': 34.0,
#      'avg_width_(ft)': 246.0,
#      'bottom_elev_(ft)': 8938.0,
#      'color_nums': 4,
#      'colors': 'bb',
#      'groomed': 0,
#      'location': 'CO',
#      'max_grade_(%)': 70.0,
#      'resort': 'Beaver Creek',
#      'slope_area_(acres)': 40.5,
#      'slope_length_(ft)': 7160.0,
#      'top_elev_(ft)': 11129.0,
#      'trail_name': 'Golden Eagle',
#      'vert_rise_(ft)': 2191.0},
#     '_type': 'runs'},
#    {'_id': '562',
#     '_index': 'ski',
#     '_score': 1.0,
#     '_source': {'ability_level': 'Advanced',
#      'ability_nums': 5,
#      'avg_grade_(%)': 21.0,
#      'avg_width_(ft)': 264.0,
#      'bottom_elev_(ft)': 8130.0,
#      'color_nums': 2,
#      'colors': 'blue',
#      'groomed': 1,
#      'location': 'CO',
#      'max_grade_(%)': 46.0,
#      'resort': 'Vail',
#      'slope_area_(acres)': 62.1,
#      'slope_length_(ft)': 10232.5,
#      'top_elev_(ft)': 10283.0,
#      'trail_name': 'Born Free',
#      'vert_rise_(ft)': 2152.9},
#     '_type': 'runs'}],
#   'max_score': 1.0,
#   'total': 3},
#  'timed_out': False,
#  'took': 12}

# %% [markdown]
# Range will give anything in the range between gte (greater than or equal to) and lte (less than or equal to)

# %%
es.search(index="ski", body={
                                "query": {
                                     "bool": {
                                         'must': {
                                             "match_phrase_prefix": {'trail_name':'Over'}
                                         },
                                         'filter': {
                                             "range": {
                                                 'vert_rise_(ft)': {"gte" : '900'}
                                             }
                                         }
                                     }
                                }
                            }
         )
# Out:
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 5, 'total': 5},
#  'hits': {'hits': [{'_id': '189',
#     '_index': 'ski',
#     '_score': 6.210478,
#     '_source': {'ability_level': 'Advanced',
#      'ability_nums': 5,
#      'avg_grade_(%)': 34.0,
#      'avg_width_(ft)': 165.0,
#      'bottom_elev_(ft)': 9925.0,
#      'color_nums': 3,
#      'colors': 'black',
#      'groomed': 0,
#      'location': 'CO',
#      'max_grade_(%)': 48.0,
#      'resort': 'Copper',
#      'slope_area_(acres)': 10.5,
#      'slope_length_(ft)': 2778.0,
#      'top_elev_(ft)': 10828.0,
#      'trail_name': 'Overlode',
#      'vert_rise_(ft)': 903.0},
#     '_type': 'runs'},
#    {'_id': '1',
#     '_index': 'ski',
#     '_score': 4.0558224,
#     '_source': {'ability_level': 'Expert',
#      'ability_nums': 6,
#      'avg_grade_(%)': 50.0,
#      'avg_width_(ft)': 319.0,
#      'bottom_elev_(ft)': 10858.0,
#      'color_nums': 4,
#      'colors': 'bb',
#      'groomed': 0,
#      'location': 'CO',
#      'max_grade_(%)': 69.0,
#      'resort': 'Loveland',
#      'slope_area_(acres)': 17.6,
#      'slope_length_(ft)': 2404.0,
#      'top_elev_(ft)': 11924.0,
#      'trail_name': 'Over the Rainbow',
#      'vert_rise_(ft)': 1066.0},
#     '_type': 'runs'}],
#   'max_score': 6.210478,
#   'total': 2},
#  'timed_out': False,
#  'took': 12}

# %% [markdown]
# Bool will search over multiple fields. Must means that must exist. Filter must exist, but the score isn't taken into account.

# %%
es.search(index="ski", body={"query": {"match": {'location':'ca'}}})
# Out:
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 5, 'total': 5},
#  'hits': {'hits': [{'_id': '370',
#     '_index': 'ski',
#     '_score': 3.1954455,
#     '_source': {'ability_level': 'Intermediate',
#      'ability_nums': 4,
#      'avg_grade_(%)': 40.0,
#      'avg_width_(ft)': 276.0,
#      'bottom_elev_(ft)': 7583.0,
#      'color_nums': 2,
#      'colors': 'blue',
#      'groomed': 1,
#      'location': 'CA',
#      'max_grade_(%)': 44.0,
#      'resort': 'Alpine Meadows',
#      'slope_area_(acres)': 4.9,
#      'slope_length_(ft)': 768.0,
#      'top_elev_(ft)': 7867.0,
#      'trail_name': 'Werner’s Schuss',
#      'vert_rise_(ft)': 284.0},
#     '_type': 'runs'},
#    {'_id': '371',
#     '_index': 'ski',
#     '_score': 3.1954455,
#     '_source': {'ability_level': 'Intermediate',
#      'ability_nums': 4,
#      'avg_grade_(%)': 32.0,
#      'avg_width_(ft)': 240.0,
#      'bottom_elev_(ft)': 7294.0,
#      'color_nums': 2,
#      'colors': 'blue',
#      'groomed': 0,
#      'location': 'CA',
#      'max_grade_(%)': 45.0,
#      'resort': 'Alpine Meadows',
#      'slope_area_(acres)': 5.2,
#      'slope_length_(ft)': 951.0,
#      'top_elev_(ft)': 7581.0,
#      'trail_name': 'Boomerang',
#      'vert_rise_(ft)': 287.0},
#     '_type': 'runs'},
#    {'_id': '380',
#     '_index': 'ski',
#     '_score': 3.1954455,
#     '_source': {'ability_level': 'Novice',
#      'ability_nums': 2,
#      'avg_grade_(%)': 9.0,
#      'avg_width_(ft)': 247.0,
#      'bottom_elev_(ft)': 6853.0,
#      'color_nums': 1,
#      'colors': 'green',
#      'groomed': 1,
#      'location': 'CA',
#      'max_grade_(%)': 20.0,
#      'resort': 'Alpine Meadows',
#      'slope_area_(acres)': 5.7,
#      'slope_length_(ft)': 997.0,
#      'top_elev_(ft)': 6946.0,
#      'trail_name': 'Subway Run',
#      'vert_rise_(ft)': 93.0},
#     '_type': 'runs'},
#    {'_id': '382',
#     '_index': 'ski',
#     '_score': 3.1954455,
#     '_source': {'ability_level': 'Advanced',
#      'ability_nums': 5,
#      'avg_grade_(%)': 33.0,
#      'avg_width_(ft)': 209.0,
#      'bottom_elev_(ft)': 7237.0,
#      'color_nums': 2,
#      'colors': 'blue',
#      'groomed': 0,
#      'location': 'CA',
#      'max_grade_(%)': 55.0,
#      'resort': 'Alpine Meadows',
#      'slope_area_(acres)': 5.9,
#      'slope_length_(ft)': 1236.0,
#      'top_elev_(ft)': 7621.0,
#      'trail_name': 'Fall Line',
#      'vert_rise_(ft)': 385.0},
#     '_type': 'runs'},
#    {'_id': '388',
#     '_index': 'ski',
#     '_score': 3.1954455,
#     '_source': {'ability_level': 'Expert',
#      'ability_nums': 6,
#      'avg_grade_(%)': 48.0,
#      'avg_width_(ft)': 854.0,
#      'bottom_elev_(ft)': 7070.0,
#      'color_nums': 3,
#      'colors': 'black',
#      'groomed': 0,
#      'location': 'CA',
#      'max_grade_(%)': 84.0,
#      'resort': 'Alpine Meadows',
#      'slope_area_(acres)': 47.2,
#      'slope_length_(ft)': 2407.0,
#      'top_elev_(ft)': 8090.0,
#      'trail_name': 'Scott Chute',
#      'vert_rise_(ft)': 1020.0},
#     '_type': 'runs'},
#    {'_id': '401',
#     '_index': 'ski',
#     '_score': 3.1954455,
#     '_source': {'ability_level': 'Low Intermediate',
#      'ability_nums': 3,
#      'avg_grade_(%)': 15.0,
#      'avg_width_(ft)': 263.0,
#      'bottom_elev_(ft)': 7434.0,
#      'color_nums': 2,
#      'colors': 'blue',
#      'groomed': 0,
#      'location': 'CA',
#      'max_grade_(%)': 29.0,
#      'resort': 'Alpine Meadows',
#      'slope_area_(acres)': 9.5,
#      'slope_length_(ft)': 1572.0,
#      'top_elev_(ft)': 7673.0,
#      'trail_name': 'Scott Meadow',
#      'vert_rise_(ft)': 239.0},
#     '_type': 'runs'},
#    {'_id': '403',
#     '_index': 'ski',
#     '_score': 3.1954455,
#     '_source': {'ability_level': 'Low Intermediate',
#      'ability_nums': 3,
#      'avg_grade_(%)': 16.0,
#      'avg_width_(ft)': 217.0,
#      'bottom_elev_(ft)': 7535.0,
#      'color_nums': 2,
#      'colors': 'blue',
#      'groomed': 1,
#      'location': 'CA',
#      'max_grade_(%)': 27.0,
#      'resort': 'Alpine Meadows',
#      'slope_area_(acres)': 4.4,
#      'slope_length_(ft)': 875.0,
#      'top_elev_(ft)': 7673.0,
#      'trail_name': 'Bobby’s Run',
#      'vert_rise_(ft)': 138.0},
#     '_type': 'runs'},
#    {'_id': '411',
#     '_index': 'ski',
#     '_score': 3.1954455,
#     '_source': {'ability_level': 'Advanced',
#      'ability_nums': 5,
#      'avg_grade_(%)': 30.0,
#      'avg_width_(ft)': 321.0,
#      'bottom_elev_(ft)': 7602.0,
#      'color_nums': 2,
#      'colors': 'blue',
#      'groomed': 1,
#      'location': 'CA',
#      'max_grade_(%)': 54.0,
#      'resort': 'Alpine Meadows',
#      'slope_area_(acres)': 8.7,
#      'slope_length_(ft)': 1175.0,
#      'top_elev_(ft)': 7932.0,
#      'trail_name': 'Terry’s Return',
#      'vert_rise_(ft)': 330.0},
#     '_type': 'runs'},
#    {'_id': '426',
#     '_index': 'ski',
#     '_score': 3.1954455,
#     '_source': {'ability_level': 'Beginner',
#      'ability_nums': 1,
#      'avg_grade_(%)': 6.0,
#      'avg_width_(ft)': 132.0,
#      'bottom_elev_(ft)': 6892.0,
#      'color_nums': 1,
#      'colors': 'green',
#      'groomed': 1,
#      'location': 'CA',
#      'max_grade_(%)': 8.0,
#      'resort': 'Alpine Meadows',
#      'slope_area_(acres)': 0.3,
#      'slope_length_(ft)': 85.0,
#      'top_elev_(ft)': 6897.0,
#      'trail_name': 'Teaching Terrain 2',
#      'vert_rise_(ft)': 5.0},
#     '_type': 'runs'},
#    {'_id': '357',
#     '_index': 'ski',
#     '_score': 2.863343,
#     '_source': {'ability_level': 'Expert',
#      'ability_nums': 6,
#      'avg_grade_(%)': 55.0,
#      'avg_width_(ft)': 251.0,
#      'bottom_elev_(ft)': 8051.0,
#      'color_nums': 3,
#      'colors': 'black',
#      'groomed': 0,
#      'location': 'CA',
#      'max_grade_(%)': 75.0,
#      'resort': 'Alpine Meadows',
#      'slope_area_(acres)': 4.1,
#      'slope_length_(ft)': 704.0,
#      'top_elev_(ft)': 8387.0,
#      'trail_name': 'D-6',
#      'vert_rise_(ft)': 336.0},
#     '_type': 'runs'}],
#   'max_score': 3.1954455,
#   'total': 74},
#  'timed_out': False,
#  'took': 8}

# %%
es.search(index="ski", body={"query": {"match_phrase_prefix": {'trail_name':'Bobby'}}})
# Out:
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 5, 'total': 5},
#  'hits': {'hits': [{'_id': '403',
#     '_index': 'ski',
#     '_score': 4.777178,
#     '_source': {'ability_level': 'Low Intermediate',
#      'ability_nums': 3,
#      'avg_grade_(%)': 16.0,
#      'avg_width_(ft)': 217.0,
#      'bottom_elev_(ft)': 7535.0,
#      'color_nums': 2,
#      'colors': 'blue',
#      'groomed': 1,
#      'location': 'CA',
#      'max_grade_(%)': 27.0,
#      'resort': 'Alpine Meadows',
#      'slope_area_(acres)': 4.4,
#      'slope_length_(ft)': 875.0,
#      'top_elev_(ft)': 7673.0,
#      'trail_name': 'Bobby’s Run',
#      'vert_rise_(ft)': 138.0},
#     '_type': 'runs'}],
#   'max_score': 4.777178,
#   'total': 1},
#  'timed_out': False,
#  'took': 3}

# %% [markdown]
# ## Get searchable fields
# and decide what to do with each

# %%
df.columns
# Out:
# Index(['trail_name', 'top_elev_(ft)', 'bottom_elev_(ft)', 'vert_rise_(ft)',
#        'slope_length_(ft)', 'avg_width_(ft)', 'slope_area_(acres)',
#        'avg_grade_(%)', 'max_grade_(%)', 'ability_level', 'resort', 'location',
#        'groomed', 'colors', 'ability_nums', 'color_nums'],
#       dtype='object')

# %% [markdown]
# 'trail_name' - match?
#
# 'top_elev_(ft)' - range
#
# 'bottom_elev_(ft)' - range
#
# 'vert_rise_(ft)' - range
#
# 'slope_length_(ft)' - range
#
# 'avg_width_(ft)' - range
#
# 'slope_area_(acres)' - range
#
# 'avg_grade_(%)' - range
#
# 'max_grade_(%)' - range
#
# 'ability_level' - ignore
#
# 'resort' - match
#
# 'location' - match
#
# 'groomed' - term
#
# 'colors' - term
#
# 'ability_nums' - ignore
#
# 'color_nums' - ignore

# %% [markdown]
# ## Working on having users enter search terms

# %%
#DEFAULTS

#trail name
tn = "Over"
#top elevation min and max
te_min = '6700'
te_max = '13000'
#bottom elevation min and max
be_min = '6700'
be_max = '13000'
#vertical rise min and max
vr_min = '4'
vr_max = '3300'
#slope length min and max
sl_min = '70'
sl_max = '31000'
#average width min and max
aw_min = '2'
aw_max = '2600'
#slope area min an d max
sa_min = '0'
sa_max = '240'
#average grade min and max
ag_min = '0'
ag_max = '80'
#max grade min and max
mg_min = '0'
mg_max = '240'
#resort
r = ['Loveland', 'Arapahoe Basin', 'Copper', 'Eldora', 'Alpine Meadows', 'Vail', 'Monarch', 'Crested Butte', 'Taos', 
     'Diamond Peak','Winter Park', 'Beaver Creek']
#location
l = ['CO', 'CA', 'NM', 'NV']
#groomed
g = ['0','1']
#color
c = ['bb', 'black', 'blue', 'green']

# %%
def search_results(
#trail name
tn = None,
#top elevation min and max
te_min = '6700',
te_max = '13000',
#bottom elevation min and max
be_min = '6700',
be_max = '13000',
#vertical rise min and max
vr_min = '4',
vr_max = '3300',
#slope length min and max
sl_min = '70',
sl_max = '31000',
#average width min and max
aw_min = '2',
aw_max = '2600',
#slope area min an d max
sa_min = '0',
sa_max = '240',
#average grade min and max
ag_min = '0',
ag_max = '80',
#max grade min and max
mg_min = '0',
mg_max = '240',
#resort
r = ['Loveland', 'Arapahoe Basin', 'Copper', 'Eldora', 'Alpine Meadows', 'Vail', 'Monarch', 'Crested Butte', 'Taos', 
     'Diamond Peak','Winter Park', 'Beaver Creek'],
#location
l = ['CO', 'CA', 'NM', 'NV'],   
#groomed
g = ['0','1'],
#color
c = ['bb', 'black', 'blue', 'green']):
    
    r = [x.split()[0].lower() for x in r]  
    l = [x.lower() for x in l]

    if tn == None:
        return es.search(index="ski", body={
                                    "query": {
                                         "bool": {
                                             'filter': [
                                                 {"range": {'top_elev_(ft)': {"gte" : te_min, "lte": te_max}}},
                                                 {"range": {'bottom_elev_(ft)': {"gte" : be_min, "lte": be_max}}},
                                                 {"range": {'vert_rise_(ft)': {"gte" : vr_min, "lte": vr_max}}},
                                                 {"range": {'slope_length_(ft)': {"gte" : sl_min, "lte": sl_max}}},
                                                 {"range": {'avg_width_(ft)': {"gte" : aw_min, "lte": aw_max}}},
                                                 {"range": {'slope_area_(acres)': {"gte" : sa_min, "lte": sa_max}}},
                                                 {"range": {'avg_grade_(%)': {"gte" : ag_min, "lte": ag_max}}},
                                                 {"range": {'max_grade_(%)': {"gte" : mg_min, "lte": mg_max}}},
                                                 {"terms": {'resort':r}},
                                                 {"terms": {'location':l}},
                                                 {"terms": {'groomed':g}},
                                                 {"terms": {'colors':c}}
                                             ]
                                         }
                                    }
                                }
             )
    return es.search(index="ski", body={
                                    "query": {
                                         "bool": {
                                             'must': {
                                                 "match": {'trail_name':tn}
                                             },
                                             'filter': [
                                                 {"range": {'top_elev_(ft)': {"gte" : te_min, "lte": te_max}}},
                                                 {"range": {'bottom_elev_(ft)': {"gte" : be_min, "lte": be_max}}},
                                                 {"range": {'vert_rise_(ft)': {"gte" : vr_min, "lte": vr_max}}},
                                                 {"range": {'slope_length_(ft)': {"gte" : sl_min, "lte": sl_max}}},
                                                 {"range": {'avg_width_(ft)': {"gte" : aw_min, "lte": aw_max}}},
                                                 {"range": {'slope_area_(acres)': {"gte" : sa_min, "lte": sa_max}}},
                                                 {"range": {'avg_grade_(%)': {"gte" : ag_min, "lte": ag_max}}},
                                                 {"range": {'max_grade_(%)': {"gte" : mg_min, "lte": mg_max}}},
                                                 {"terms": {'resort': r}},
                                                 {"terms": {'location':l}},
                                                 {"terms": {'groomed':g}},
                                                 {"terms": {'colors':c}}
                                             ],
                                         }
                                    }
                                }
             )

# %%
search_results(r = ['Winter Park'], c = ['green', 'blue'], mg_min = '10', mg_max = '20')
# Out:
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 5, 'total': 5},
#  'hits': {'hits': [{'_id': '852',
#     '_index': 'ski',
#     '_score': 0.0,
#     '_source': {'ability_level': 'Novice',
#      'ability_nums': 2,
#      'avg_grade_(%)': 10.0,
#      'avg_width_(ft)': 367.0,
#      'bottom_elev_(ft)': 9390.0,
#      'color_nums': 1,
#      'colors': 'green',
#      'groomed': 1,
#      'location': 'CO',
#      'max_grade_(%)': 14.0,
#      'resort': 'Winter Park',
#      'slope_area_(acres)': 8.47,
#      'slope_length_(ft)': 1680.76,
#      'top_elev_(ft)': 9565.0,
#      'trail_name': 'Porcupine',
#      'vert_rise_(ft)': 175.0},
#     '_type': 'runs'},
#    {'_id': '933',
#     '_index': 'ski',
#     '_score': 0.0,
#     '_source': {'ability_level': 'Beginner',
#      'ability_nums': 1,
#      'avg_grade_(%)': 10.0,
#      'avg_width_(ft)': 112.0,
#      'bottom_elev_(ft)': 9450.0,
#      'color_nums': 1,
#      'colors': 'green',
#      'groomed': 1,
#      'location': 'CO',
#      'max_grade_(%)': 14.0,
#      'resort': 'Winter Park',
#      'slope_area_(acres)': 5.88,
#      'slope_length_(ft)': 1258.66,
#      'top_elev_(ft)': 9580.0,
#      'trail_name': 'Shoo Fly',
#      'vert_rise_(ft)': 130.0},
#     '_type': 'runs'},
#    {'_id': '935',
#     '_index': 'ski',
#     '_score': 0.0,
#     '_source': {'ability_level': 'Novice',
#      'ability_nums': 2,
#      'avg_grade_(%)': 9.0,
#      'avg_width_(ft)': 20.0,
#      'bottom_elev_(ft)': 9090.0,
#      'color_nums': 1,
#      'colors': 'green',
#      'groomed': 0,
#      'location': 'CO',
#      'max_grade_(%)': 18.0,
#      'resort': 'Winter Park',
#      'slope_area_(acres)': 3.13,
#      'slope_length_(ft)': 4008.76,
#      'top_elev_(ft)': 9460.0,
#      'trail_name': 'Corridor',
#      'vert_rise_(ft)': 370.0},
#     '_type': 'runs'},
#    {'_id': '980',
#     '_index': 'ski',
#     '_score': 0.0,
#     '_source': {'ability_level': 'Low Intermediate',
#      'ability_nums': 3,
#      'avg_grade_(%)': 11.0,
#      'avg_width_(ft)': 50.0,
#      'bottom_elev_(ft)': 10450.0,
#      'color_nums': 1,
#      'colors': 'green',
#      'groomed': 1,
#      'location': 'CO',
#      'max_grade_(%)': 12.0,
#      'resort': 'Winter Park',
#      'slope_area_(acres)': 4.0,
#      'slope_length_(ft)': 1991.16,
#      'top_elev_(ft)': 10670.0,
#      'trail_name': 'Gunbarrel',
#      'vert_rise_(ft)': 220.0},
#     '_type': 'runs'},
#    {'_id': '892',
#     '_index': 'ski',
#     '_score': 0.0,
#     '_source': {'ability_level': 'Novice',
#      'ability_nums': 2,
#      'avg_grade_(%)': 10.0,
#      'avg_width_(ft)': 59.0,
#      'bottom_elev_(ft)': 9950.0,
#      'color_nums': 2,
#      'colors': 'blue',
#      'groomed': 0,
#      'location': 'CO',
#      'max_grade_(%)': 10.0,
#      'resort': 'Winter Park',
#      'slope_area_(acres)': 0.51,
#      'slope_length_(ft)': 720.38,
#      'top_elev_(ft)': 10025.0,
#      'trail_name': 'Upper Rendezvous',
#      'vert_rise_(ft)': 75.0},
#     '_type': 'runs'},
#    {'_id': '903',
#     '_index': 'ski',
#     '_score': 0.0,
#     '_source': {'ability_level': 'Novice',
#      'ability_nums': 2,
#      'avg_grade_(%)': 10.0,
#      'avg_width_(ft)': 100.0,
#      'bottom_elev_(ft)': 9845.0,
#      'color_nums': 2,
#      'colors': 'blue',
#      'groomed': 0,
#      'location': 'CO',
#      'max_grade_(%)': 10.0,
#      'resort': 'Winter Park',
#      'slope_area_(acres)': 0.25,
#      'slope_length_(ft)': 1513.46,
#      'top_elev_(ft)': 10000.0,
#      'trail_name': 'Dilly Dally Alley',
#      'vert_rise_(ft)': 155.0},
#     '_type': 'runs'},
#    {'_id': '905',
#     '_index': 'ski',
#     '_score': 0.0,
#     '_source': {'ability_level': 'Novice',
#      'ability_nums': 2,
#      'avg_grade_(%)': 16.0,
#      'avg_width_(ft)': 86.0,
#      'bottom_elev_(ft)': 10920.0,
#      'color_nums': 1,
#      'colors': 'green',
#      'groomed': 1,
#      'location': 'CO',
#      'max_grade_(%)': 17.0,
#      'resort': 'Winter Park',
#      'slope_area_(acres)': 2.26,
#      'slope_length_(ft)': 841.63,
#      'top_elev_(ft)': 11050.0,
#      'trail_name': 'Hobo Alley',
#      'vert_rise_(ft)': 130.0},
#     '_type': 'runs'},
#    {'_id': '965',
#     '_index': 'ski',
#     '_score': 0.0,
#     '_source': {'ability_level': 'Low Intermediate',
#      'ability_nums': 3,
#      'avg_grade_(%)': 10.0,
#      'avg_width_(ft)': 40.0,
#      'bottom_elev_(ft)': 9580.0,
#      'color_nums': 2,
#      'colors': 'blue',
#      'groomed': 1,
#      'location': 'CO',
#      'max_grade_(%)': 19.0,
#      'resort': 'Winter Park',
#      'slope_area_(acres)': 13.48,
#      'slope_length_(ft)': 7438.18,
#      'top_elev_(ft)': 10340.0,
#      'trail_name': 'Corona Way',
#      'vert_rise_(ft)': 760.0},
#     '_type': 'runs'},
#    {'_id': '964',
#     '_index': 'ski',
#     '_score': 0.0,
#     '_source': {'ability_level': 'Intermediate',
#      'ability_nums': 4,
#      'avg_grade_(%)': 16.0,
#      'avg_width_(ft)': 177.0,
#      'bottom_elev_(ft)': 10240.0,
#      'color_nums': 2,
#      'colors': 'blue',
#      'groomed': 0,
#      'location': 'CO',
#      'max_grade_(%)': 15.0,
#      'resort': 'Winter Park',
#      'slope_area_(acres)': 25.75,
#      'slope_length_(ft)': 6087.07,
#      'top_elev_(ft)': 11200.0,
#      'trail_name': 'Edelweiss',
#      'vert_rise_(ft)': 960.0},
#     '_type': 'runs'},
#    {'_id': '967',
#     '_index': 'ski',
#     '_score': 0.0,
#     '_source': {'ability_level': 'Low Intermediate',
#      'ability_nums': 3,
#      'avg_grade_(%)': 14.0,
#      'avg_width_(ft)': 133.0,
#      'bottom_elev_(ft)': 9655.0,
#      'color_nums': 1,
#      'colors': 'green',
#      'groomed': 0,
#      'location': 'CO',
#      'max_grade_(%)': 17.0,
#      'resort': 'Winter Park',
#      'slope_area_(acres)': 2.77,
#      'slope_length_(ft)': 904.61,
#      'top_elev_(ft)': 9780.0,
#      'trail_name': 'Tin Horn',
#      'vert_rise_(ft)': 125.0},
#     '_type': 'runs'}],
#   'max_score': 0.0,
#   'total': 23},
#  'timed_out': False,
#  'took': 10}

# %% [markdown]
# ## Use search_results function to query!
# if search term not specified, will use default
#
# resort, location, groomed, and color must be in a list (even if only one value)
#
# see DEFAULTS for what values can be searched and what their variable names are

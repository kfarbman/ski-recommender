# %%
run comb_tables.py
# Out:
# /home/karen/Documents/ski-recommender/BC_table.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['top_elev_(ft)'][df['trail_name'] == 'Beginner Terrain'] = df['bottom_elev_(ft)'] + df['vert_rise_(ft)']
# /home/karen/Documents/ski-recommender/comb_tables.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   whole_table['ability_level'][whole_table['ability_level'] == 'Advanced Intermediate'] = 'Advanced'
# /home/karen/Documents/ski-recommender/comb_tables.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
run webscrape_trails.py

# %%
loveland_greens
# Out:
# ['All Smiles',
#  'Boomerang',
#  'Catwalk',
#  'Creek Trail',
#  'Deuces Bowl',
#  'Fail Safe',
#  'Fire Bowl',
#  'Forest Meadow',
#  'Homerun',
#  'Lower Creek Trail',
#  'Mambo',
#  'North Turtle Creek',
#  'South Turtle Creek',
#  'Take Off',
#  'Tango Road',
#  'Turtle Creek',
#  'Zig Zag']

# %%
loveland['class'] = 'color'
loveland['class'][loveland['trail_name'].isin(loveland_greens)] = 'green'
loveland['class'][loveland['trail_name'].isin(loveland_blues)] = 'blue'
loveland['class'][loveland['trail_name'].isin(loveland_blacks)] = 'black'
loveland['class'][loveland['trail_name'].isin(loveland_bbs)] = 'double black'
# Out:
# /home/karen/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /home/karen/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/karen/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py:5233: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
loveland[['trail_name','ability_level']][loveland['class'] == 'color']
# Out:
#              trail_name     ability_level
# 6       Upper Richard's      Intermediate
# 7              Cat Walk  Low Intermediate
# 10            Cats Meow            Expert
# 14              Tempest      Intermediate
# 16           T-bar Road  Low Intermediate
# 17                       Low Intermediate
# 18             Home Run            Novice
# 26       Apollo (Lower)            Expert
# 27       Apollo (Upper)          Advanced
# 31         North Chutes          Advanced
# 33    Fail Safe Trees I          Advanced
# 34   Fail Safe Trees II            Expert
# 37      Sunburst Chutes            Expert
# 48    Blackjack (Lower)            Novice
# 49    Blackjack (Upper)      Intermediate
# 53           Sani Flush      Intermediate
# 54          Deuces Wild  Low Intermediate
# 60           Chet's Run      Intermediate
# 61       Hook 'Em Horns          Advanced
# 64           Awesome II          Advanced
# 68             Rip Curl          Advanced
# ...

# %%
for trail in loveland_greens:
    if trail not in list(loveland['trail_name']):
         print(trail)
# Out:
# Catwalk
# Deuces Bowl
# Homerun
# Zig Zag

# %%
for trail in loveland_blues:
    if trail not in list(loveland['trail_name']):
         print(trail)
# Out:
# Apollo
# Blackjack
# North Chutes #1
# North Chutes #2
# Stardust
# Switchback
# Twist

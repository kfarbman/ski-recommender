# %%
import pickle
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity, euclidean_distances
from sklearn.preprocessing import StandardScaler
import warnings
warnings.filterwarnings('ignore')

# %%
pkl_file = open('../data/df.pkl', 'rb')
df = pickle.load(pkl_file)
pkl_file.close()

# %%
features = [
            'top_elev_(ft)', 
            'bottom_elev_(ft)', 
            'vert_rise_(ft)', 
            'slope_length_(ft)', 
            'avg_width_(ft)', 
            'slope_area_(acres)', 
            'avg_grade_(%)', 
            'max_grade_(%)', 
            'groomed']

X = df[features].values

# %%
def cos_sim_recommendations(trail_name, resort_name, X, n=5, resort=None):
    index = df.index[(df['trail_name'] == trail_name) & (df['resort'] == resort_name)][0]
    trail = X[index].reshape(1,-1)
    cs = cosine_similarity(trail, X)
    rec_index = np.argsort(cs)[0][::-1][1:]
    ordered_df = df.loc[rec_index]
    if resort:
        ordered_df = ordered_df[ordered_df['resort'] == resort]
    rec_df = ordered_df.head(n)
    orig_row = df.loc[[index]].rename(lambda x: 'original')
    total = pd.concat((orig_row,rec_df))
    return total

# %%
def eucl_dist_recommendations_resort(trail_name, resort_name, X, n=5, resort=None):
    index = df.index[(df['trail_name'] == trail_name) & (df['resort'] == resort_name)][0]
    trail = X[index].reshape(1,-1)
    ed = euclidean_distances(trail, X)
    rec_index = np.argsort(ed)[0][::-1][1:]
    ordered_df = df.loc[rec_index]
    if resort:
        ordered_df = ordered_df[ordered_df['resort'] == resort]
    rec_df = ordered_df.head(n)
    orig_row = df.loc[[index]].rename(lambda x: 'original')
    total = pd.concat((orig_row,rec_df))
    return total

# %%
ss = StandardScaler()
X = ss.fit_transform(X)

# %%
cos_sim_recommendations('Sorensen Park','Winter Park',X,n=5)
# Out:
#                trail_name  top_elev_(ft)  bottom_elev_(ft)  vert_rise_(ft)  \
# original    Sorensen Park         9150.0            9090.0            60.0
# 932              Shoo Fly         9580.0            9450.0           130.0
# 314       Little Hawk TRV         9369.0            9348.0            21.0
# 852                Bobcat         9490.0            9400.0            90.0
# 308              Fox Tail         9511.0            9456.0            56.0
# 317          Sunkid Slope         9361.0            9354.0             8.0
#
#           slope_length_(ft)  avg_width_(ft)  slope_area_(acres)  \
# original            1067.43           114.0                4.07
# 932                 1258.66           112.0                5.88
# 314                  821.00            67.0                1.30
# 852                  822.96           137.0                1.53
# 308                  749.00            61.0                1.00
# 317                  157.00            67.0                0.20
#
#           avg_grade_(%)  max_grade_(%) ability_level       resort location  \
# original            6.0            8.0      Beginner  Winter Park       CO
# 932                10.0           14.0      Beginner  Winter Park       CO
# 314                 3.0            8.0      Beginner       Eldora       CO
# 852                11.0            9.0        Novice  Winter Park       CO
# 308                 7.0           12.0        Novice       Eldora       CO
# 317                 6.0            6.0      Beginner       Eldora       CO
#
#           groomed colors  ability_nums  color_nums
# original        1  green             1           1
# 932             1  green             1           1
# 314             1  green             1           1
# 852             1  green             2           1
# 308             1  green             2           1
# 317             1   blue             1           2

# %%
eucl_dist_recommendations_resort('Sorensen Park','Winter Park',X,n=5,resort=None)
# Out:
#                   trail_name  top_elev_(ft)  bottom_elev_(ft)  vert_rise_(ft)  \
# original       Sorensen Park         9150.0            9090.0            60.0
# 1021                   Cinch        10901.0            8108.0          2793.0
# 1007         Alphabet Chutes        11700.0           11350.0           350.0
# 583       Inner MongoliaBowl        11495.0           10226.0          1269.1
# 1018      Stone Creek Chutes        10900.0            9420.0          1480.0
# 1001           Belle Fourche        11400.0           10740.0           660.0
#
#           slope_length_(ft)  avg_width_(ft)  slope_area_(acres)  \
# original            1067.43          114.00                4.07
# 1021               30653.00           38.00               26.50
# 1007                 694.98         2117.26               33.78
# 583                 3877.60         2187.00              194.60
# 1018                7946.00          987.00              180.00
# 1001                2101.48         2491.12              120.18
#
#           avg_grade_(%)  max_grade_(%) ability_level        resort location  \
# original            6.0            8.0      Beginner   Winter Park       CO
# 1021                9.0           13.0        Novice  Beaver Creek       CO
# 1007               58.0          236.0        Expert   Winter Park       CO
# 583                33.0           58.0      Advanced          Vail       CO
# 1018               32.0           85.0        Expert  Beaver Creek       CO
# 1001               33.0           51.0        Expert   Winter Park       CO
#
#           groomed colors  ability_nums  color_nums
# original        1  green             1           1
# 1021            1  green             2           1
# 1007            0     bb             6           4
# 583             0  black             5           3
# 1018            0     bb             6           4
# 1001            0  black             6           3

# %%
'''least similar'''
cs = cosine_similarity(X[0].reshape(1,-1), X)[0]
css = list(enumerate(cs))
srtd = sorted(css, key=lambda x: x[1])[::-1]
srtd[-5:]
# Out:
# [(333, -0.9410708817093416),
#  (308, -0.9413197094749598),
#  (932, -0.9466683118520665),
#  (314, -0.9581932537348332),
#  (848, -0.9661414996247434)]

# %%
df.iloc[[0,673,821,848,314,403]]
# Out:
#                  trail_name  top_elev_(ft)  bottom_elev_(ft)  vert_rise_(ft)  \
# 0          Over the Rainbow        11924.0           10858.0          1066.0
# 673  Bubba’s Shortcut Upper        10335.0           10238.0            97.0
# 821             School Yard         6799.0            6732.0            66.0
# 848           Sorensen Park         9150.0            9090.0            60.0
# 314         Little Hawk TRV         9369.0            9348.0            21.0
# 403      Lakeview to Weasel         7538.0            7483.0            55.0
#
#      slope_length_(ft)  avg_width_(ft)  slope_area_(acres)  avg_grade_(%)  \
# 0              2404.00           319.0               17.60           50.0
# 673            1200.00           118.0                3.30            8.0
# 821             980.00           129.0                2.90            7.0
# 848            1067.43           114.0                4.07            6.0
# 314             821.00            67.0                1.30            3.0
# 403            1282.00           106.0                3.10            4.0
#
#      max_grade_(%) ability_level          resort location  groomed colors  \
# 0             69.0        Expert        Loveland       CO        0     bb
# 673           11.0        Novice   Crested Butte       CO        1  green
# 821            9.0      Beginner    Diamond Peak       NV        1  green
# 848            8.0      Beginner     Winter Park       CO        1  green
# 314            8.0      Beginner          Eldora       CO        1  green
# 403           18.0        Novice  Alpine Meadows       CA        1   blue
#
#      ability_nums  color_nums
# 0               6           4
# 673             2           1
# 821             1           1
# 848             1           1
# 314             1           1
# 403             2           2

# %%
color = ['green','blue']

# %%
def cos_sim_recs(index, n=5, resort=None, color=None):
    trail = X[index].reshape(1,-1)
    cs = cosine_similarity(trail, X)
    rec_index = np.argsort(cs)[0][::-1][1:]
    ordered_df = df.loc[rec_index]
    if resort:
        ordered_df = ordered_df[ordered_df['resort'] == resort]
    if color:
        ordered_df = ordered_df[ordered_df['colors'].isin(color)]
    rec_df = ordered_df.head(n)
    rec_df = rec_df.reset_index(drop=True)
    rec_df.index = rec_df.index+1
    orig_row = df.loc[[index]].rename(lambda x: 'original')
    total = pd.concat((orig_row,rec_df))
    return total

# %%
cos_sim_recs(901,n=10,color=color)
# Out:
#                       trail_name  top_elev_(ft)  bottom_elev_(ft)  \
# original      Whistle Stop Lower        10800.0           10640.0
# 1             Upper White Rabbit        10800.0           10600.0
# 2                   Minor Matter        10677.0           10479.0
# 3                      Gunbarrel        10670.0           10450.0
# 4                     Tango Road        11121.0           10999.0
# 5              Silver Queen Road        11242.0           11074.0
# 6                          I-Way        10735.0           10638.0
# 7                       Chisholm        11130.0           11003.0
# 8              Tin Pants Catwalk        11023.0           10971.0
# 9                         Peanut        10320.0           10165.0
# 10        Bubba’s Shortcut Upper        10335.0           10238.0
#
#           vert_rise_(ft)  slope_length_(ft)  avg_width_(ft)  \
# original           160.0            1876.64            79.0
# 1                  200.0            1902.59           124.0
# 2                  198.0            1723.00           100.0
# 3                  220.0            1991.16            50.0
# 4                  123.0            1297.00            97.0
# 5                  168.0            2050.00            36.0
# 6                   97.0            1063.00            64.0
# 7                  127.0            1488.00            41.0
# 8                   51.3             681.60            38.0
# 9                  156.0            1833.00            35.0
# 10                  97.0            1200.00           118.0
#
#           slope_area_(acres)  avg_grade_(%)  max_grade_(%)     ability_level  \
# original                4.74            9.0           13.0            Novice
# 1                       4.52           11.0           16.0            Novice
# 2                       4.00           12.0           18.0            Novice
# 3                       4.00           11.0           12.0  Low Intermediate
# 4                       2.90           10.0           16.0            Novice
# 5                       1.70            8.0           16.0  Low Intermediate
# 6                       1.60            9.0           19.0            Novice
# 7                       1.40            9.0           18.0            Novice
# 8                       0.60            8.0           10.0          Beginner
# 9                       1.50            9.0           15.0            Novice
# 10                      3.30            8.0           11.0            Novice
#
#                   resort location  groomed colors  ability_nums  color_nums
# original     Winter Park       CO        1  green             2           1
# 1            Winter Park       CO        1   blue             2           2
# 2                 Copper       CO        1  green             2           1
# 3            Winter Park       CO        1  green             3           1
# 4               Loveland       CO        1  green             2           1
# 5          Crested Butte       CO        1   blue             3           2
# 6                 Copper       CO        1  green             2           1
# 7         Arapahoe Basin       CO        1  green             2           1
# 8                   Vail       CO        1  green             1           1
# 9          Crested Butte       CO        1  green             2           1
# 10         Crested Butte       CO        1  green             2           1
